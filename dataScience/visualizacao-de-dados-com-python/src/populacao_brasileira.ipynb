# %% [markdown]
# #Criando gráficos com massa de dados em CSV
# Importando dados do GitHub

# %%
import pandas as pd

# Pegando os dados diretamente do git
url = 'https://raw.githubusercontent.com/Red-of-Pallet/Estudo/dataScience/dataScience/populacao_brasileira/populacao_brasileira.csv'

df1 = pd.read_csv(url, delimiter=';')
df1.head()
# Out:
# Running cells with 'Python 3.8.10' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/geovane.alves/AppData/Local/Microsoft/WindowsApps/python3.8.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
import numpy as np
import matplotlib.pyplot as plt

# Titulos
plt.title('Crescimento da População Brasileira 1980-2016')
plt.xlabel('Ano')
plt.ylabel('População x100.000.000')

# Dados
plt.plot(df1['ano'], df1['population'], color='k', linestyle='--')
plt.bar(df1['ano'], df1['population'], color='#D3D3D3')

plt.show()
